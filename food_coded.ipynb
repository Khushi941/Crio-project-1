# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("food_coded.csv")

# %%
data = data.drop_duplicates()

# %%
data.dropna()
# Out:
#             GPA  Gender  breakfast  calories_chicken  calories_day  \
# 1         3.654       1          1               610           3.0
# 2           3.3       1          1               720           4.0
# 4           3.5       1          1               720           2.0
# 6           3.8       2          1               610           3.0
# 7           3.3       1          1               720           3.0
# 9           3.3       1          1               430           3.0
# 10          3.5       1          1               610           3.0
# 11        3.904       1          1               720           4.0
# 12          3.4       2          1               430           3.0
# 13          3.6       1          1               610           3.0
# 14          3.1       2          1               610           3.0
# 17          3.6       2          1               430           3.0
# 18          3.4       1          1               720           3.0
# ...

# %%
data.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# ...

# %%
columns = [
    'Gender', 'breakfast', 'comfort_food', 'comfort_food_reasons', 'cuisine','diet_current', 'drink', 'eating_changes', 'eating_changes_coded','eating_changes_coded1', 'ethnic_food', 'fav_cuisine', 'fav_food','food_childhood', 'grade_level', 'greek_food', 'healthy_meal','ideal_diet', 'ideal_diet_coded', 'indian_food', 'italian_food','life_rewarding', 'marital_status', 'meals_dinner_friend','nutritional_check', 'parents_cook', 'persian_food', 'self_perception_weight','sports', 'thai_food', 'type_sports'
]
value_counts = data[columns].apply(pd.Series.value_counts)

# %%
correlation_matrix = data.corr()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2200\2558734126.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
selected_data = ['cook', 'eating_out', 'employment', 'ethnic_food', 'exercise', 'fruit_day', 'income', 'on_off_campus', 'pay_meal_out', 'sports', 'veggies_day']

plt.figure(figsize=(10, 6))

sns.boxplot(data=data[selected_data])

plt.title("Distribution of Selected Features")
plt.xlabel("Features")
plt.ylabel("Values")

plt.xticks(rotation=45)

plt.show()
